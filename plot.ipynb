# %%
"""
Production-Level Library Human Detection System
Enhanced version with improved UI, statistics, logging, and configuration management
"""
import sys
import os

# Add current directory to path for imports
sys.path.insert(0, os.path.dirname(os.path.abspath('')))

# Import the production-level detection system
from detection_system import HumanDetectionSystem
from utils import print_banner, print_success, print_info

# Initialize and run the production-level detection system
print_banner()
print_info("Initializing Library Human Detection System...")
print_info("Using configuration from config.json")

# Create and run the system
system = HumanDetectionSystem(config_path="config.json")
system.run()
# Out:
# ...
# GMAIL APP PASSWORD REQUIRED
# ...
#
# You MUST use a Gmail App Password (NOT your regular password).
#
# STEP-BY-STEP INSTRUCTIONS:
# 1. Go to: https://myaccount.google.com/
# 2. Click 'Security' in the left sidebar
# 3. Enable '2-Step Verification' if not already enabled
#    (This is REQUIRED to generate App Passwords)
# 4. After enabling, go back to Security page
# 5. Click 'App passwords' (appears after 2-Step Verification)
# 6. Select:
#    - App: 'Mail'
#    - Device: 'Other (Custom name)'
#    - Name: Enter 'Python Script' or any name
# 7. Click 'Generate'
# 8. Copy the 16-character password (it looks like: xxxx xxxx xxxx xxxx)
# 9. Paste it here (you can include or remove spaces)
#
# Direct link: https://myaccount.google.com/apppasswords
# ...
#
# ✓ App Password accepted!
# Image saved: C:\Users\Sudhanva Patil\OneDrive\Pictures\New folder\person_detected_20251210_144257.jpg
# ✓ Email sent successfully to bgnanasagar72@gmail.com
# ...
